# %%
import os
import tarfile
import json

from PIL import Image

# %%
path = "/raid/8wiehe/deploy.laion.ai/8f83b608504d46bb81708ec86e912220/your_output_folder/"

tar_files = [f for f in os.listdir(path) if f.endswith(".tar")]

# %%
tar = tarfile.open(path + tar_files[1])

# %%
names = tar.getnames()
json_names = [n for n in names if n.endswith(".json")]

# %%
tar_files[0]
# Out:
# '04915.tar'

# %%
Image.open(tar.extractfile(names[0]))
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=256x256 at 0x7F5DAB774220>

# %%
tar.extractfil

# %%
members = tar.getmembers()

# %%
len(names) / 2 * len(tar_files)
# Out:
# 86965389.0

# %%
names[:3]
# Out:
# ['049150011.jpg', '049150011.json', '049150011.txt']

# %%
i = 3

# %%
Image.open(tar.extractfile(members[i * 2]))
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=256x256 at 0x7F5DAB5AF550>

# %%
meta_data = json.load(tar.extractfile(members[i * 2 + 1]))

# %%
meta_data
# Out:
# {'NSFW': 'UNLIKELY',
#  'similarity': 0.3540211319923401,
#  'LICENSE': '?',
#  'caption': "Cotton jewelry box, 'Noble Flowers' - Cotton Jewelry Box in Taupe with Beaded Floral Motifs",
#  'url': 'http://images1.novica.net/pictures/15/p296550_1.jpg',
#  'key': '049150003',
#  'status': 'success',
#  'error_message': None,
#  'width': 256,
#  'height': 256,
#  'exif': '{"Image Orientation": "Horizontal (normal)", "Image XResolution": "72", "Image YResolution": "72", "Image ResolutionUnit": "Pixels/Inch", "Image ExifOffset": "90", "EXIF ExifVersion": "0210", "EXIF FlashPixVersion": "0100", "EXIF ColorSpace": "Uncalibrated", "EXIF ExifImageWidth": "200", "EXIF ExifImageLength": "200"}',
#  'original_width': 200,
#  'original_height': 200}

# %%
meta_data
# Out:
# {'NSFW': 'UNSURE',
#  'similarity': 0.3525753319263458,
#  'LICENSE': '?',
#  'caption': 'Russell Athletic - 10% Off Clothing Order',
#  'url': 'http://c1.dealcatcher.com/merchant_images/small/russell_athletic970.png',
#  'key': '049150011',
#  'status': 'success',
#  'error_message': None,
#  'width': 256,
#  'height': 256,
#  'exif': '{}',
#  'original_width': 80,
#  'original_height': 50}
